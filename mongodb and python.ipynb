# %%
import pymongo

# %%
url = "mongodb+srv://mayurmhaiske01_db_user:12345@cluster0.zksidtp.mongodb.net/?appName=Cluster0"

# %%
client = pymongo.MongoClient(url)

# %%
db = client["sample_mflix"]

# %%
coll = db["theaters"]

# %%
data = coll.find()

# %%
list(data)
# Out:
# [{'_id': ObjectId('59a47286cfa9a3a73e51e72c'),
#   'theaterId': 1000,
#   'location': {'address': {'street1': '340 W Market',
#     'city': 'Bloomington',
#     'state': 'MN',
#     'zipcode': '55425'},
#    'geo': {'type': 'Point', 'coordinates': [-93.24565, 44.85466]}}},
#  {'_id': ObjectId('59a47286cfa9a3a73e51e72d'),
#   'theaterId': 1003,
#   'location': {'address': {'street1': '45235 Worth Ave.',
#     'city': 'California',
#     'state': 'MD',
#     'zipcode': '20619'},
#    'geo': {'type': 'Point', 'coordinates': [-76.512016, 38.29697]}}},
#  {'_id': ObjectId('59a47286cfa9a3a73e51e72e'),
#   'theaterId': 1008,
#   'location': {'address': {'street1': '1621 E Monte Vista Ave',
#     'city': 'Vacaville',
#     'state': 'CA',
#     'zipcode': '95688'},
#    'geo': {'type': 'Point', 'coordinates': [-121.96328, 38.367649]}}},
#  {'_id': ObjectId('59a47286cfa9a3a73e51e72f'),
#   'theaterId': 1004,
#   'location': {'address': {'street1': '5072 Pinnacle Sq',
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(list(data))

# %%
df.tail()
# Out:
#                            _id  theaterId  \
# 1559  59a47287cfa9a3a73e51ed43        940
# 1560  59a47287cfa9a3a73e51ed44        951
# 1561  59a47287cfa9a3a73e51ed45        949
# 1562  59a47287cfa9a3a73e51ed46        952
# 1563  59a47287cfa9a3a73e51ed47        953
#
#                                                location
# 1559  {'address': {'street1': '4310 Buffalo Gap Rd',...
# 1560  {'address': {'street1': '91 Silhavy Rd', 'stre...
# 1561  {'address': {'street1': '2651 S Rochester Rd',...
# 1562  {'address': {'street1': '4620 Garth Rd', 'city...
# 1563  {'address': {'street1': '10 McKenna Rd', 'city...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1564 entries, 0 to 1563
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   _id        1564 non-null   object
#  1   theaterId  1564 non-null   int64
#  2   location   1564 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 36.8+ KB
